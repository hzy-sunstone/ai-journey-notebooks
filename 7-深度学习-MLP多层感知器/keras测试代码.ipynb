# %%
#建立一个Sequential顺序模型
from keras.models import Sequential
model = Sequential()

# %%
#通过.add()叠加各层网络
from keras.layers import Dense
model.add(Dense(units=3, activation='sigmoid', input_dim=3))
model.add(Dense(units=1, activation='sigmoid'))
# Out:
# D:\Anaconda3\envs\ai\lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#查看模型结构
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 3)                   │              12 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │               4 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 16 (64.00 B)
#  Trainable params: 16 (64.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
#通过.compile配置模型求解过程参数
model.compile(loss='categorical_crossentropy',
                optimizer='sgd',
                metrics=['accuracy'])

# %%
#训练模型
model.fit(x_train, y_train, epochs=5)

# %%
import tensorflow as tf
print("是否支持CUDA（GPU加速）：", tf.test.is_built_with_cuda())
print("是否检测到GPU：", tf.config.list_physical_devices('GPU'))
# Out:
# 是否支持CUDA（GPU加速）： False
# 是否检测到GPU： []

# %%
import numpy as np
import matplotlib.pyplot as plt

# 生成一个5×5的随机二维数组
data = np.random.rand(5, 5)  # 数值范围0-1
plt.imshow(data, cmap='viridis')  # cmap指定颜色映射
plt.colorbar()  # 显示颜色对应的数值
plt.title('随机二维数组的imshow可视化')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 5, 6])
plt.title("中文标题测试")  # 含中文
plt.xlabel("横轴标签")
plt.ylabel("纵轴标签")
plt.show()
