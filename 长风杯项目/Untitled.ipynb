# %%
import pandas as pd
import numpy as np
city=pd.read_csv('快运企业数据集/city.csv')
city.head()
# Out:
#       id province name  adcode  citycode   latitude   longitude    pid
# 0      3      河南省  洛阳市  410300       379  34.619702  112.453895      2
# 1    297      河南省  漯河市  411100       395  33.580380  114.016600      2
# 2  25690      江苏省  扬州市  321000       514  32.394404  119.412834  25325
# 3  22074      福建省  南平市  350700       599  27.382829  118.081325  21579
# 4  12221      辽宁省  盘锦市  211100       427  40.719560  122.170729  11149

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig=plt.figure(figsize=(10,10))
plt.scatter(city.loc[:,'latitude'],city.loc[:,'longitude'])
plt.title('城市地理分布')
# Out:
# Text(0.5, 1.0, '城市地理分布')
